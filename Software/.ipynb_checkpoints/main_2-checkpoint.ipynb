# %%
# import packages
import numpy as np
import os
import time
import pandas as pd
import spectral.io.envi as envi
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.collections as collections

import scipy as scipy
from scipy import linalg, optimize
from scipy.optimize import curve_fit
from scipy import signal
from scipy.ndimage.filters import generic_filter
from scipy.stats import mode
from scipy.signal import savgol_filter

import sys
from sys import stdout

from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.linear_model import LinearRegression

# %%
# set the path to the LAI measurement file
LAI_SM_file = "C:/Users/J_F/Desktop/Uni/Master/Semester_3/Geo_418/Daten_Messungen/Hausarbeit/AUSWERTUNG_LAI.slb.hdr"

# load the data & metadata
lib_in = envi.open(LAI_SM_file)
spec = lib_in.spectra
names = lib_in.names
nspec = spec.shape[0]
nbands= spec.shape[1]
wavel =  lib_in.bands.centers
fwhm =  lib_in.bands.bandwidths 
units =  lib_in.bands.band_unit

# %%
print(names)
print(spec.shape)
print(units)
print(wavel)
# Out:
# ['Soil', 'LAI 0.5', 'LAI 1', 'LAI 2', 'LAI 3', 'LAI 4']
# (6, 2151)
# Nanometers
# ...

# %%
plt.plot(wavel, spec[0,:], "tab:brown")
plt.plot(wavel, spec[1,:], "y")
plt.plot(wavel, spec[2,:], "lawngreen")
plt.plot(wavel, spec[3,:], "limegreen")
plt.plot(wavel, spec[4,:], "green")
plt.plot(wavel, spec[5,:], "darkgreen")

plt.ylabel("Reflektanz")
plt.xlabel("Wellenlänge [nm]")
plt.legend(["Boden", "LAI 0,5", "LAI 1", "LAI 2", "LAI 3", "LAI 4"])
plt.savefig("LAI.png", dpi = 600)

# %%
NDVI = (spec[:,580]-spec[:,350])/(spec[:,580]+spec[:,350])
print(NDVI)
# Out:
# [0.14598542 0.57188609 0.61725825 0.70087849 0.72498456 0.75017139]

# %%
LAI = [0, 0.5, 1, 2, 3, 4]

# %%
plt.plot(LAI, NDVI, "ko")
plt.plot(LAI, NDVI, "k", linestyle = "dashed")
plt.xlabel("LAI")
plt.ylabel("NDVI")
plt.savefig("LAI_NDVI.png", dpi = 600)
